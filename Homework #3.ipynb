# %%
#question 2
def function_2(n):
    num = 8
    while n < num: 
        print (n) 
        n = n**2 
        print(n)
    else: 
        print("greater than", num)
        
function_2 (3)
# Out:
# 3
# 9
# greater than 8

# %%
#question 2
function_2 (10)
# Out:
# greater than 8

# %%
#question 5
import math
def function_5A(v1, v2): 
    return sum(range(v1, v2)) / len(range(v1, v2))
    
function_5A(1, 100)
# Out:
# 50.0

# %%
#question 5
def function_5B(v1, v2):
    return sum(range(v1, v2))

function_5B(1, 100)
# Out:
# 4950

# %%
#question 5
import statistics as stats
def function_5C (v1, v2):
    return stats.pstdev(range(v1, v2))

function_5C(1, 100)
# Out:
# 28.577380332470412

# %%
#question 6
def minimal(v1, v2, v3, v4):
    return min(v1, v2, v3, v4)
    
minimal(6, 8, 9, 5)
# Out:
# 5

# %%
#question 1 
marks = {'Andy':88, 'Amy':66, 'James': 90, 'Jules': 55, 'Arthur': 77}

# %%
#question 1a
def grades(name):
    for name, score in marks.items():
        return score
    else: 
        print("cannot find students name")
    
grades('Steve')
# Out:
# 88

# %%
#question 1b
def average1(v):
    for k, v in marks.items():
        return sum(v)/len(v)
    
average1(v)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [210], in <cell line: 6>()
#       3     for k, v in marks.items():
#       4         return sum(v)/len(v)
# ----> 6 average1(v)
#
# NameError: name 'v' is not defined

# %%
#question 3

def sums(num):
    while range(1, num):
        return sum(range(1, num))
    
    
sums(5)
# Out:
# 10

# %%
#question 4
def function4(v1, v2):
    for n in range(v1, v2):
        return sum(range(v1, v2))
        
function4(1, 8)
# Out:
# 28

# %%
#question 7

def concat(name, number):
    for i in range(concatenated_list):
        return(f' {i}: {concatenated_list}')

concat('Olivia', 24)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [215], in <cell line: 7>()
#       4     for i in range(concatenated_list):
#       5         return(f' {i}: {concatenated_list}')
# ----> 7 concat('Olivia', 24)
#
# Input In [215], in concat(name, number)
#       3 def concat(name, number):
# ----> 4     for i in range(concatenated_list):
#       5         return(f' {i}: {concatenated_list}')
#
# NameError: name 'concatenated_list' is not defined
