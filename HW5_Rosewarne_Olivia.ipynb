# %%
#QUESTION 1
matrix5 = matrix(c(7,2,9,4,12,13), nrow = 2, ncol = 3)
matrix5
matrix6 = matrix(c(1,2,3,7,8,9,12,13,14,19,20,21), nrow = 3, ncol = 4)
matrix6
matrix5 %*% matrix6
# Out:
#      [,1] [,2] [,3]
# [1,] 7    9    12
# [2,] 2    4    13
#      [,1] [,2] [,3] [,4]
# [1,] 1    7    12   19
# [2,] 2    8    13   20
# [3,] 3    9    14   21
#      [,1] [,2] [,3] [,4]
# [1,] 61   229  369  565
# [2,] 49   163  258  391

# %%
#QUESTION 2
#a
Data_Frame <- data.frame(
  id = c(1,2,3,4,5),
  name = c("Peter", "Amy", "Ryan", "Gary", "Michelle"),
  salary = c(623.30, 515.20, 611.00, 729.00, 843.25)
)
Data_Frame
# Out:
#   id name     salary
# 1 1  Peter    623.30
# 2 2  Amy      515.20
# 3 3  Ryan     611.00
# 4 4  Gary     729.00
# 5 5  Michelle 843.25

# %%
#b
new_column_df = cbind(Data_Frame, departments = c("engineering", "finance", "tech", "communications", "marketing"))
new_column_df
# Out:
#   id name     salary departments
# 1 1  Peter    623.30 engineering
# 2 2  Amy      515.20 finance
# 3 3  Ryan     611.00 tech
# 4 4  Gary     729.00 communications
# 5 5  Michelle 843.25 marketing

# %%
#c
new_dataframe = new_column_df[-c(1,3,5), -c(2,3)]
new_dataframe
# Out:
#   id departments
# 2 2  finance
# 4 4  communications

# %%
#d
x1 = c(new_column_df[c(1,4,5), 3])
mylabels = c(new_column_df[c(1,4,5), 2])
colors = c("orange", "green", "purple")
barplot(height = x1, xlab = 'names', ylab='salaries', names.arg = mylabels, col = colors)
# Out:
# plot without title

# %%
#e
x2 = c(summary(new_column_df[c(1, 4,5), 3]))
x2
pie(x = x2[c(1,3,6)], main = "Summary of Salaries")
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
# 623.300 676.150 729.000 731.850 786.125 843.250
# Plot with title “Summary of Salaries”
